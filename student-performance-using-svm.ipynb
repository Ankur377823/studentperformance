# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv("/kaggle/input/student-factor/StudentPerformanceFactors.csv")
dataset.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
dataset.shape
# Out:
# (6607, 20)

# %%
sns.pairplot(dataset)

# %%
dataset.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
dataset["Parental_Involvement"].value_counts()
# Out:
# Parental_Involvement
# Medium    3362
# High      1908
# Low       1337
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()
dataset['Parental_Involvement']=la.fit_transform(dataset["Parental_Involvement"])

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   int64
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
dataset.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement Access_to_Resources  \
# 0             23          84                     1                High
# 1             19          64                     1              Medium
# 2             24          98                     2              Medium
# 3             29          89                     1              Medium
# 4             19          92                     2              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# ...

# %%
df=dataset.select_dtypes(include=["object"]).columns

# %%
for i in df:
    dataset[i]=pd.DataFrame(la.fit_transform(dataset[i]))

# %%
dataset.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             23          84                     1                    0
# 1             19          64                     1                    2
# 2             24          98                     2                    2
# 3             29          89                     1                    2
# 4             19          92                     2                    2
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                           0            7               73                 1
# 1                           0            8               59                 1
# 2                           1            7               91                 2
# 3                           1            8               98                 2
# 4                           1            6               65                 2
#
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data=dataset.corr(),annot=True)
# Out:
# <Axes: >

# %%
dataset.isnull().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %%
dataset.head()
# Out:
#    Hours_Studied  Attendance  Parental_Involvement  Access_to_Resources  \
# 0             23          84                     1                    0
# 1             19          64                     1                    2
# 2             24          98                     2                    2
# 3             29          89                     1                    2
# 4             19          92                     2                    2
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                           0            7               73                 1
# 1                           0            8               59                 1
# 2                           1            7               91                 2
# 3                           1            8               98                 2
# 4                           1            6               65                 2
#
# ...

# %%
x=dataset.iloc[:,:-1]
y=dataset['Exam_Score']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVR
svr=SVR(C= 1000, gamma= 0.001, kernel= 'rbf')
svr.fit(x_train,y_train)
# Out:
# SVR(C=1000, gamma=0.001)

# %%
from sklearn.model_selection import GridSearchCV 
  

param_grid = {'C': [0.1, 1, 10, 100, 1000],  
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001], 
              'kernel': ['rbf']}  
  
grid = GridSearchCV(svr, param_grid, refit = True, verbose = 3) 
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.000 total time=   1.7s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.000 total time=   1.7s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.004 total time=   1.8s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.001 total time=   1.7s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=rbf;, score=-0.001 total time=   1.7s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.060 total time=   1.4s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.060 total time=   1.5s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.047 total time=   1.4s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.048 total time=   1.5s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.045 total time=   1.5s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.589 total time=   1.2s
# ...

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
svr.score(x_test,y_test),svr.score(x_train,y_train)
# Out:
# (0.7440342692377813, 0.7031879214696746)

# %%
from sklearn.metrics import mean_squared_error
y_pred=svr.predict(x)
mse=mean_squared_error(y,y_pred)
mse
# Out:
# 4.375737275599754
